# %%
# !python -m venv venv
source venv/bin/activate  # Windows: venv\Scripts\activate
pip install fastmcp pymupdf sentence-transformers chromadb ollama
# Out:
#   Cell In[3], line 2
#     source venv/bin/activate  # Windows: venv\Scripts\activate
#            ^
# SyntaxError: invalid syntax
